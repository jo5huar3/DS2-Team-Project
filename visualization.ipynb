# %%
from lorenz63_plots import *

# %%
T = 50.0
burn_in_time = 5.0  # drop first 5 time-units for histograms


x0 = (1.0, 1.0, 1.0)

# Simulate

# %%
dt_01 = 0.01

t_01, X_01 = simulate_lorenz63(x0=x0, dt=dt_01, T=T)

# Optional: save to CSV
df = pd.DataFrame({"t": t_01, "x": X_01[:, 0], "y": X_01[:, 1], "z": X_01[:, 2]})
df.to_csv("lorenz63_dt001_T50.csv", index=False)

plot_timeseries_subplots(t_01, X_01, dt_01)
plot_histograms_subplots(X_01, dt_01, burn_in_time=burn_in_time)

# %%
dt_005 = 0.005

# Simulate
t_005, X_005 = simulate_lorenz63(x0=x0, dt=dt_005, T=T)
plot_timeseries_subplots(t_005, X_005, dt_005)
plot_histograms_subplots(X_005, dt_005, burn_in_time=burn_in_time)

# %%
dt_001 = 0.001

# Simulate
t_001, X_001 = simulate_lorenz63(x0=x0, dt=dt_001, T=T)
plot_timeseries_subplots(t_001, X_001, dt_001)
plot_histograms_subplots(X_001, dt_001, burn_in_time=burn_in_time)
